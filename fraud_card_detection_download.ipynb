# %% [markdown]
# Jai rishabh dev

# %%
# !pip install matplotlib

# %%
# pip install seaborn

# %% [markdown]
# ## importing python libraries

# %%
import numpy as np
import pandas as pd
import sklearn
import scipy
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # DATA ACQUISITION

# %%
df = pd.read_csv('fraudTrain.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
df.tail()
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  \
# 1296670     1296670   2020-06-21 12:12:08       30263540414123
# 1296671     1296671   2020-06-21 12:12:19     6011149206456997
# 1296672     1296672   2020-06-21 12:12:32     3514865930894695
# 1296673     1296673   2020-06-21 12:13:36     2720012583106919
# 1296674     1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt  \
# 1296670                    fraud_Reichel Inc  entertainment   15.56
# 1296671             fraud_Abernathy and Sons    food_dining   51.70
# 1296672                 fraud_Stiedemann Ltd    food_dining  105.93
# 1296673  fraud_Reinger, Weissnat and Strosin    food_dining   74.90
# 1296674  fraud_Langosh, Wintheiser and Hyatt    food_dining    4.30
#
#                first       last gender                         street  ...  \
# 1296670         Erik  Patterson      M       162 Jessica Row Apt. 072  ...
# ...

# %%
df.shape
# Out:
# (1296675, 23)

# %% [markdown]
# ### DATA PRE_PROCESSING FOR TRAIN SET DATA

# %%
df.isnull().sum()  #to find the missing values in the each column of dataset
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0                 int64
# trans_date_trans_time     object
# cc_num                     int64
# merchant                  object
# category                  object
# amt                      float64
# first                     object
# last                      object
# gender                    object
# street                    object
# city                      object
# state                     object
# zip                        int64
# lat                      float64
# long                     float64
# city_pop                   int64
# job                       object
# dob                       object
# trans_num                 object
# unix_time                  int64
# merch_lat                float64
# merch_long               float64
# is_fraud                   int64
# dtype: object

# %% [markdown]
# ### DELETE Unnecessary columns from dataset

# %%
newdf = df

# %%
newdf.drop(columns =["Unnamed: 0", "trans_num", "street"], inplace = True)

# %%
df.shape
# Out:
# (1296675, 20)

# %% [markdown]
# ##### make learn to machine capable n data rows

# %%
data = df.head(n= 25550)
               
data.is_fraud.value_counts()
# Out:
# is_fraud
# 0    25324
# 1      226
# Name: count, dtype: int64

# %%
unique_merchant = data['merchant'].nunique()
unique_merchant
# Out:
# 693

# %%
unique_trans_date_time = data['trans_date_trans_time'].nunique()
unique_trans_date_time
# Out:
# 25237

# %%
unique_category = data['category'].nunique()
unique_category
# Out:
# 14

# %%
unique_first = data['first'].nunique()
unique_first
# Out:
# 337

# %%
unique_last = data['last'].nunique()
unique_last
# Out:
# 465

# %%
unique_gender = data['gender'].nunique()
unique_gender
# Out:
# 2

# %%
unique_job = data['job'].nunique()
unique_job
# Out:
# 475

# %%
unique_city = data['city'].nunique()
unique_city
# Out:
# 836

# %%
unique_state = data['state'].nunique()
unique_state
# Out:
# 50

# %%
unique_dob = data['dob'].nunique()
unique_dob
# Out:
# 895

# %% [markdown]
# #### so after adding all the unique items we get 50+836+475+2+465+337+14+25237+693+895 + "10" already existing column = 29014

# %%
df_transform = pd.get_dummies(data = data)
df_transform
# Out:
#                  cc_num     amt    zip      lat      long  city_pop  \
# 0      2703186189652095    4.97  28654  36.0788  -81.1781      3495
# 1          630423337322  107.23  99160  48.8878 -118.2105       149
# 2        38859492057661  220.11  83252  42.1808 -112.2620      4154
# 3      3534093764340240   45.00  59632  46.2306 -112.1138      1939
# 4       375534208663984   41.96  24433  38.4207  -79.4629        99
# ...                 ...     ...    ...      ...       ...       ...
# 25545  3523898249167098   45.20  10463  40.8798  -73.9067   1382480
# 25546  3598895972308782   78.34  44857  41.2403  -82.6078     23805
# 25547  4908846471916297  138.43  76050  32.2779  -97.2351      5875
# 25548  4449530933957323   51.79  94971  38.2427 -122.9145       337
# 25549   371009169330125  100.71  31771  31.2462  -83.6549      5666
#
#         unix_time  merch_lat  merch_long  is_fraud  ...  dob_2001-07-10  \
# 0      1325376018  36.011293  -82.048315         0  ...           False
# ...

# %%
df_transform.shape
# Out:
# (25550, 29014)

# %%
# df_transform.iloc[:, 25500:25520]

# %% [markdown]
# ##### selecting input data and target data

# %%
x_train = df_transform.drop(columns = 'is_fraud', axis =1)
y_train = df_transform['is_fraud']

# %%
x_train.shape
# Out:
# (25550, 29013)

# %%
y_train.shape
# Out:
# (25550,)

# %% [markdown]
# # Now  for Test Data Set

# %%
df_test = pd.read_csv("fraudTest.csv")

# %%
df_test.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
df_test.drop(columns = ["Unnamed: 0", "trans_num", "street"], inplace = True)

# %%
df_test
# Out:
#        trans_date_trans_time            cc_num  \
# 0        2020-06-21 12:14:25  2291163933867244
# 1        2020-06-21 12:14:33  3573030041201292
# 2        2020-06-21 12:14:53  3598215285024754
# 3        2020-06-21 12:15:15  3591919803438423
# 4        2020-06-21 12:15:17  3526826139003047
# ...                      ...               ...
# 555714   2020-12-31 23:59:07    30560609640617
# 555715   2020-12-31 23:59:09  3556613125071656
# 555716   2020-12-31 23:59:15  6011724471098086
# 555717   2020-12-31 23:59:24     4079773899158
# 555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# 2       fraud_Swaniawski, Nitzsche and Welch  health_fitness   41.28   Ashley
# 3                          fraud_Haley Group        misc_pos   60.05    Brian
# ...

# %%
#Its a better practice to always shuffle a test data so that our model do not overfit and we can able to determine its actual capability

# %%
data_test = df_test.sample(frac = 1, random_state = 1).reset_index()

# %%
data_test
# Out:
#          index trans_date_trans_time               cc_num  \
# 0       207181   2020-09-01 17:00:35     4229733778084049
# 1       501018   2020-12-20 06:31:50  4223708906367574214
# 2       312515   2020-10-18 10:05:33       30175986190993
# 3       407433   2020-11-29 05:16:30         675909898057
# 4       386454   2020-11-19 08:28:43       30092964733035
# ...        ...                   ...                  ...
# 555714  371403   2020-11-12 19:04:33         639023984367
# 555715  491263   2020-12-17 17:56:59     4452366298769043
# 555716  470924   2020-12-13 14:46:21     3546674063249004
# 555717  491755   2020-12-17 20:52:13     4069975342931683
# 555718  128037   2020-08-04 16:08:36     3558652751678952
#
#                                       merchant       category    amt  \
# 0                       fraud_Bernier and Sons      kids_pets  41.17
# 1                         fraud_McCullough LLC       misc_pos  51.89
# ...

# %%
# _100th_row = data_test.iloc[99]
# _100th_row

# %%
#print row index with 1

# %%
# row1 = data_test.iloc[1]

# %%
# row1

# %%
#PRINT DESIRED ROW

# %%
FIRSTROW = data_test[data_test['index'] == 1]
FIRSTROW
# Out:
#         index trans_date_trans_time            cc_num              merchant  \
# 184217      1   2020-06-21 12:14:33  3573030041201292  fraud_Sporer-Keebler
#
#              category    amt   first      last gender     city  ...    zip  \
# 184217  personal_care  29.84  Joanne  Williams      F  Altonah  ...  84002
#
#             lat     long  city_pop                     job         dob  \
# 184217  40.3207 -110.436       302  Sales professional, IT  1990-01-17
#
#          unix_time  merch_lat  merch_long  is_fraud
# 184217  1371816873  39.450498 -109.960431         0
#
# [1 rows x 21 columns]

# %% [markdown]
# ###### TAKE TEST DATA UP TO 5000 ROWS

# %%
data_test = data_test.head(n=5000)

# %%
data_test.is_fraud.value_counts()
# Out:
# is_fraud
# 0    4979
# 1      21
# Name: count, dtype: int64

# %%
data_test.zip.value_counts()
# Out:
# zip
# 82514    20
# 28405    20
# 99323    19
# 61454    19
# 34112    18
#          ..
# 6365      1
# 48202     1
# 97492     1
# 46946     1
# 96136     1
# Name: count, Length: 866, dtype: int64

# %%
unique = data_test['zip'].nunique()
unique
# Out:
# 866

# %%
new_data = data_test.drop(columns = 'index' , axis = 1)
new_data.shape
# Out:
# (5000, 20)

# %%
df_transform = pd.get_dummies(data = new_data)
df_transform
# Out:
#                    cc_num     amt    zip      lat      long  city_pop  \
# 0        4229733778084049   41.17  42701  37.6848  -85.8784     48194
# 1     4223708906367574214   51.89  45051  39.0965  -84.6431       177
# 2          30175986190993    2.22  56592  47.5375  -95.9941       516
# 3            675909898057   87.21  10504  41.1360  -73.7009      7987
# 4          30092964733035   79.78  41056  38.6207  -83.8067     14228
# ...                   ...     ...    ...      ...       ...       ...
# 4995        4169388510116   30.92  14537  43.0330  -77.1575       207
# 4996       36722699017270   77.00  85173  33.2887 -111.0985      2872
# 4997      370877495212014  483.95  28659  36.2017  -81.1286     21134
# 4998     4099707841315751  132.76  22968  38.2586  -78.4074      9815
# 4999     2291163933867244  130.36  29209  33.9659  -80.9355    333497
#
#        unix_time  merch_lat  merch_long  is_fraud  ...  dob_2001-07-10  \
# ...

# %%
data_test
# Out:
#        index trans_date_trans_time               cc_num  \
# 0     207181   2020-09-01 17:00:35     4229733778084049
# 1     501018   2020-12-20 06:31:50  4223708906367574214
# 2     312515   2020-10-18 10:05:33       30175986190993
# 3     407433   2020-11-29 05:16:30         675909898057
# 4     386454   2020-11-19 08:28:43       30092964733035
# ...      ...                   ...                  ...
# 4995  276550   2020-10-02 10:32:54        4169388510116
# 4996   16702   2020-06-27 05:28:38       36722699017270
# 4997   72934   2020-07-16 14:19:19      370877495212014
# 4998  288038   2020-10-06 19:30:18     4099707841315751
# 4999   95565   2020-07-24 18:08:13     2291163933867244
#
#                                          merchant        category     amt  \
# 0                          fraud_Bernier and Sons       kids_pets   41.17
# 1                            fraud_McCullough LLC        misc_pos   51.89
# ...

# %%
x_test= df_transform.drop(columns = 'is_fraud', axis = 1)
y_test = df_transform['is_fraud']

# %%
fit_columns = x_train.columns
fit_columns
# Out:
# Index(['cc_num', 'amt', 'zip', 'lat', 'long', 'city_pop', 'unix_time',
#        'merch_lat', 'merch_long', 'trans_date_trans_time_2019-01-01 00:00:18',
#        ...
#        'dob_2001-07-10', 'dob_2001-07-26', 'dob_2001-12-19', 'dob_2003-05-07',
#        'dob_2003-09-14', 'dob_2004-03-18', 'dob_2004-05-08', 'dob_2004-06-19',
#        'dob_2004-12-30', 'dob_2005-01-29'],
#       dtype='object', length=29013)

# %%
x_test = x_test.reindex(columns = fit_columns, fill_value = 0)

# %% [markdown]
# #### NOW we Know that this Problem is related to classification so we will use supervised machine learning classification algorithm

# %% [markdown]
# #### CLASSIFICARTION ALGORITHM in Supervised Machine Learning
# #### LOGISTIC Regression
# #### Support vector machine
# #### decision tree classifier
# #### random forest classifier
# #### Naive Baye

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression(solver = 'liblinear')
LR.fit(x_train, y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
predictions = LR.predict(x_test)

# %%
predictions[4999]
# Out:
# 0

# %%
predict_probability = LR.predict_proba(x_test)

# %%
predict_probability
# Out:
# array([[0.50142882, 0.49857118],
#        [0.99668891, 0.00331109],
#        [0.50001019, 0.49998981],
#        ...,
#        [0.50012528, 0.49987472],
#        [0.5013849 , 0.4986151 ],
#        [0.50077397, 0.49922603]])

# %% [markdown]
# # import  Evaluations Matrices

# %%
import sklearn.metrics as metrics
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import classification_report

# %%
LR_Accuracy_Score = accuracy_score(y_test, predictions)

# %%
LR_Accuracy_Score
# Out:
# 0.9958

# %%
print(confusion_matrix(predictions, y_test))
# Out:
# [[4979   21]
#  [   0    0]]

# %% [markdown]
# ### Classification Report

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4979
#            1       0.00      0.00      0.00        21
#
#     accuracy                           1.00      5000
#    macro avg       0.50      0.50      0.50      5000
# weighted avg       0.99      1.00      0.99      5000
# C:\Users\gjgau\pythonanaconda\envs\notebook\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\gjgau\pythonanaconda\envs\notebook\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# # Import Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree = DecisionTreeClassifier()
tree.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = tree.predict(x_test)

# %% [markdown]
# # Import Evaluation Metrices of Trees

# %%
from sklearn.metrics import jaccard_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### classification Report

# %%
print(classification_report(predictions , y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4972
#            1       0.67      0.50      0.57        28
#
#     accuracy                           1.00      5000
#    macro avg       0.83      0.75      0.78      5000
# weighted avg       1.00      1.00      1.00      5000

# %% [markdown]
# ### Confusion Metrics

# %%
print(confusion_matrix(predictions, y_test))
# Out:
# [[4965    7]
#  [  14   14]]

# %%
Tree_Accuracy_score = accuracy_score(y_test, predictions)
Tree_Accuracy_score
# Out:
# 0.9958

# %%
Tree_Jaccard_index = jaccard_score(y_test, predictions)
Tree_Jaccard_index
# Out:
# 0.4

# %% [markdown]
# # KNN Supervised Machine Learning ALgorithm

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 4)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
predicitions = knn.predict(x_test)

# %%
from sklearn.metrics import classification_report , confusion_matrix

# %% [markdown]
# ### Classification Report

# %%
print(classification_report(y_test , predictions))
print(confusion_matrix(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4979
#            1       0.50      0.67      0.57        21
#
#     accuracy                           1.00      5000
#    macro avg       0.75      0.83      0.78      5000
# weighted avg       1.00      1.00      1.00      5000
#
# [[4965   14]
#  [   7   14]]

# %% [markdown]
# # Choosing K Value
# #### use elbow method to pick a good K value

# %%
new_y_test = y_test.iloc[0:100]
new_y_test
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 95    0
# 96    0
# 97    0
# 98    0
# 99    0
# Name: is_fraud, Length: 100, dtype: int64

# %%
new_x_test = x_test.iloc[0:100]
new_x_test
# Out:
#                  cc_num     amt    zip      lat     long  city_pop  \
# 0      4229733778084049   41.17  42701  37.6848 -85.8784     48194
# 1   4223708906367574214   51.89  45051  39.0965 -84.6431       177
# 2        30175986190993    2.22  56592  47.5375 -95.9941       516
# 3          675909898057   87.21  10504  41.1360 -73.7009      7987
# 4        30092964733035   79.78  41056  38.6207 -83.8067     14228
# ..                  ...     ...    ...      ...      ...       ...
# 95        4783226709001    4.36  67556  38.5957 -99.5540       320
# 96      341283058448499  124.76  39825  30.9788 -84.7373      1461
# 97  4599735407877245080   34.41  38079  36.3846 -89.4649      5577
# 98       38199021865320   70.70   3601  43.1960 -72.3001       477
# 99      213193596103206   85.14  49775  45.7549 -84.4470        95
#
#      unix_time  merch_lat  merch_long  \
# 0   1378054835  38.370429  -86.671765
# 1   1387521110  39.090859  -84.115650
# 2   1382090733  47.285136  -96.180797
# ...

# %%
new_xtrain = x_train.iloc[0:100]
new_xtrain
new_ytrain = y_train.iloc[0:100]

# %%
# knn = knn.fit(new_xtrain, new_ytrain)

# %%
# new_pred = knn.predict(new_x_test)

# %%
error_rate = []
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(new_xtrain, new_ytrain)
    pred_i = knn.predict(new_x_test)
    error_rate.append(np.mean(pred_i != new_y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate, color = 'blue', linestyle = '--', marker = 'o', markerfacecolor = 'red', markersize = 10)
plt.title('Error Rate vs K')
plt.xlabel('K')
plt.ylabel("Error Rate")
# Out:
# Text(0, 0.5, 'Error Rate')

# %% [markdown]
# ##### so we can take any k value

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators = 300)

# %%
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=300)

# %%
#Predictions

# %%
Predictions = rfc.predict(x_test)

# %%
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4979
#            1       0.50      0.67      0.57        21
#
#     accuracy                           1.00      5000
#    macro avg       0.75      0.83      0.78      5000
# weighted avg       1.00      1.00      1.00      5000
#
# [[4965   14]
#  [   7   14]]
